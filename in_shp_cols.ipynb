# %% [markdown]
# program to check the columns in india shapefile

# %%
import geopandas as gpd

# load the shapefile
gdf = gpd.read_file('in_shp/in.shp')

# print just the column names
print("Columns in the shapefile:")
print(gdf.columns.tolist())

# show the first 5 rows to preview the attributes
gdf.head()
# Out:
# Columns in the shapefile:
# ['id', 'name', 'source', 'geometry']
#      id                 name                  source  \
# 0  INAN  Andaman and Nicobar  https://simplemaps.com
# 1  INTG            Telangana  https://simplemaps.com
# 2  INAP       Andhra Pradesh  https://simplemaps.com
# 3  INAR    Arunachal Pradesh  https://simplemaps.com
# 4  INAS                Assam  https://simplemaps.com
#
#                                             geometry
# 0  MULTIPOLYGON (((93.84805 7.24028, 93.8425 7.22...
# 1  POLYGON ((77.50945 15.92086, 77.51488 15.96315...
# 2  MULTIPOLYGON (((77.50945 15.92086, 77.58842 15...
# 3  POLYGON ((95.23763 26.68629, 95.23611 26.71221...
# 4  MULTIPOLYGON (((92.10789 26.89382, 92.12037 26...
